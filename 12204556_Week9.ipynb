# %% [markdown]
# <a href="https://colab.research.google.com/github/ElyorS/AI-application-system/blob/main/12204556_Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import SimpleRNN
import logging
tf.get_logger().setLevel(logging.ERROR)

EPOCHS = 100
BATCH_SIZE = 16
TRAIN_TEST_SPLIT = 0.8
MIN = 12
FILE_NAME = 'book_store_sales.csv'

def readfile(file_name):
    file = open(file_name, 'r', encoding='utf-8')
    next(file)
    data = []
    for line in (file):
        values = line.split(',')
        data.append(float (values [1]))
    file.close()
    return np.array(data, dtype=np.float32)

# Read data and split into training and test data.
sales = readfile(FILE_NAME)
months = len(sales)
split = int(months * TRAIN_TEST_SPLIT)
train_sales = sales [0:split]
test_sales = sales [split:]

# %%
# Plot dataset
x = range(len(sales))
plt.plot(x, sales, 'r-', label='book sales')
plt.title('Book store sales')
plt.axis([0, 339, 0.0, 3000.0])
plt.xlabel('Months')
plt.ylabel('Sales(millions $)')
plt.legend()
plt.show()

# %%
# Plot naive prediction
test_output = test_sales[MIN:]
naive_prediction = test_sales[MIN-1:-1]
x = range(len(test_output))
plt.plot(x, test_output, 'g-', label='test_output')
plt.plot (x, naive_prediction, 'm-', label='naive prediction')
plt.title('Book store sales')
plt.axis([0, len(test_output), 0.0, 3000.0])
plt.xlabel ('months')
plt.ylabel('Monthly book store sales')
plt.legend()
plt.show ()

# %%
# Standardize train and test data.
# Use only training seasons to compute mean and stddev.
mean = np.mean(train_sales)
stddev = np.std(train_sales)
train_sales_std = (train_sales - mean)/stddev
test_sales_std = (test_sales - mean)/stddev

# %%
# Create training examples.
train_months = len(train_sales)
train_X = np.zeros ((train_months-MIN, train_months-1, 1))
train_y = np.zeros ((train_months-MIN, 1))
for i in range(0, train_months-MIN):
    train_X[i, -(i+MIN):, 0] = train_sales_std[0:i+MIN]
    train_y[i, 0] = train_sales_std[i+MIN]
# Create test examples.
test_months = len (test_sales)
test_X = np.zeros ((test_months-MIN, test_months-1, 1))
test_y = np.zeros ((test_months-MIN, 1))
for i in range(0, test_months-MIN) :
    test_X[i, - (i+MIN) :, 0] = test_sales_std[0:i+MIN]
    test_y[i, 0] = test_sales_std[i+MIN]

# %%
# Create RNN model
model = Sequential()
model.add(SimpleRNN(128, activation='relu', input_shape= (None, 1)))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer = 'adam', metrics = ['mean_absolute_error'])
model. summary ()
history = model.fit(train_X, train_y, validation_data = (test_X, test_y), epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2, shuffle=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 128)               16640
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 16769 (65.50 KB)
# Trainable params: 16769 (65.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 17/17 - 3s - loss: 0.7887 - mean_absolute_error: 0.6510 - val_loss: 0.7383 - val_mean_absolute_error: 0.7852 - 3s/epoch - 150ms/step
# Epoch 2/100
# 17/17 - 1s - loss: 0.4779 - mean_absolute_error: 0.5355 - val_loss: 0.2773 - val_mean_absolute_error: 0.4547 - 803ms/epoch - 47ms/step
# Epoch 3/100
# 17/17 - 1s - loss: 0.2889 - mean_absolute_error: 0.4169 - val_loss: 0.2449 - val_mean_absolute_error: 0.4370 - 726ms/epoch - 43ms/step
# Epoch 4/100
# 17/17 - 1s - loss: 0.1397 - mean_absolute_error: 0.2874 - val_loss: 0.1080 - val_mean_absolute_error: 0.2314 - 844ms/epoch - 50ms/step
# Epoch 5/100
# 17/17 - 1s - loss: 0.0664 - mean_absolute_error: 0.1982 - val_loss: 0.0958 - val_mean_absolute_error: 0.2164 - 826ms/epoch - 49ms/step
# Epoch 6/100
# 17/17 - 1s - loss: 0.0722 - mean_absolute_error: 0.1956 - val_loss: 0.0561 - val_mean_absolute_error: 0.1593 - 1s/epoch - 70ms/step
# Epoch 7/100
# 17/17 - 2s - loss: 0.0650 - mean_absolute_error: 0.1857 - val_loss: 0.0644 - val_mean_absolute_error: 0.1754 - 2s/epoch - 93ms/step
# Epoch 8/100
# 17/17 - 1s - loss: 0.0437 - mean_absolute_error: 0.1549 - val_loss: 0.0455 - val_mean_absolute_error: 0.1377 - 930ms/epoch - 55ms/step
# Epoch 9/100
# 17/17 - 1s - loss: 0.0363 - mean_absolute_error: 0.1426 - val_loss: 0.0597 - val_mean_absolute_error: 0.1829 - 769ms/epoch - 45ms/step
# Epoch 10/100
# 17/17 - 1s - loss: 0.0600 - mean_absolute_error: 0.1766 - val_loss: 0.0448 - val_mean_absolute_error: 0.1503 - 782ms/epoch - 46ms/step
# Epoch 11/100
# 17/17 - 1s - loss: 0.0355 - mean_absolute_error: 0.1532 - val_loss: 0.0366 - val_mean_absolute_error: 0.1229 - 782ms/epoch - 46ms/step
# Epoch 12/100
# 17/17 - 1s - loss: 0.0282 - mean_absolute_error: 0.1273 - val_loss: 0.0402 - val_mean_absolute_error: 0.1373 - 736ms/epoch - 43ms/step
# Epoch 13/100
# 17/17 - 1s - loss: 0.0281 - mean_absolute_error: 0.1256 - val_loss: 0.0359 - val_mean_absolute_error: 0.1265 - 739ms/epoch - 43ms/step
# Epoch 14/100
# 17/17 - 1s - loss: 0.0232 - mean_absolute_error: 0.1175 - val_loss: 0.0392 - val_mean_absolute_error: 0.1429 - 746ms/epoch - 44ms/step
# Epoch 15/100
# 17/17 - 1s - loss: 0.0224 - mean_absolute_error: 0.1166 - val_loss: 0.0361 - val_mean_absolute_error: 0.1196 - 729ms/epoch - 43ms/step
# Epoch 16/100
# 17/17 - 1s - loss: 0.0243 - mean_absolute_error: 0.1171 - val_loss: 0.0420 - val_mean_absolute_error: 0.1471 - 782ms/epoch - 46ms/step
# Epoch 17/100
# 17/17 - 1s - loss: 0.0258 - mean_absolute_error: 0.1192 - val_loss: 0.0266 - val_mean_absolute_error: 0.1092 - 799ms/epoch - 47ms/step
# Epoch 18/100
# 17/17 - 1s - loss: 0.0236 - mean_absolute_error: 0.1176 - val_loss: 0.0350 - val_mean_absolute_error: 0.1277 - 750ms/epoch - 44ms/step
# Epoch 19/100
# 17/17 - 1s - loss: 0.0216 - mean_absolute_error: 0.1067 - val_loss: 0.0404 - val_mean_absolute_error: 0.1311 - 759ms/epoch - 45ms/step
# Epoch 20/100
# 17/17 - 1s - loss: 0.0270 - mean_absolute_error: 0.1243 - val_loss: 0.0345 - val_mean_absolute_error: 0.1333 - 741ms/epoch - 44ms/step
# Epoch 21/100
# 17/17 - 1s - loss: 0.0241 - mean_absolute_error: 0.1184 - val_loss: 0.0382 - val_mean_absolute_error: 0.1372 - 1s/epoch - 76ms/step
# Epoch 22/100
# 17/17 - 1s - loss: 0.0197 - mean_absolute_error: 0.1078 - val_loss: 0.0424 - val_mean_absolute_error: 0.1377 - 1s/epoch - 88ms/step
# Epoch 23/100
# 17/17 - 1s - loss: 0.0198 - mean_absolute_error: 0.0998 - val_loss: 0.0256 - val_mean_absolute_error: 0.0986 - 817ms/epoch - 48ms/step
# Epoch 24/100
# 17/17 - 1s - loss: 0.0175 - mean_absolute_error: 0.0997 - val_loss: 0.0363 - val_mean_absolute_error: 0.1361 - 747ms/epoch - 44ms/step
# Epoch 25/100
# 17/17 - 1s - loss: 0.0181 - mean_absolute_error: 0.0983 - val_loss: 0.0272 - val_mean_absolute_error: 0.1093 - 725ms/epoch - 43ms/step
# Epoch 26/100
# 17/17 - 1s - loss: 0.0158 - mean_absolute_error: 0.0933 - val_loss: 0.0443 - val_mean_absolute_error: 0.1354 - 790ms/epoch - 46ms/step
# Epoch 27/100
# 17/17 - 1s - loss: 0.0153 - mean_absolute_error: 0.0889 - val_loss: 0.0449 - val_mean_absolute_error: 0.1485 - 758ms/epoch - 45ms/step
# Epoch 28/100
# 17/17 - 1s - loss: 0.0177 - mean_absolute_error: 0.0949 - val_loss: 0.0342 - val_mean_absolute_error: 0.1246 - 838ms/epoch - 49ms/step
# Epoch 29/100
# 17/17 - 1s - loss: 0.0160 - mean_absolute_error: 0.0948 - val_loss: 0.0321 - val_mean_absolute_error: 0.1223 - 801ms/epoch - 47ms/step
# Epoch 30/100
# 17/17 - 1s - loss: 0.0144 - mean_absolute_error: 0.0881 - val_loss: 0.0420 - val_mean_absolute_error: 0.1472 - 758ms/epoch - 45ms/step
# Epoch 31/100
# 17/17 - 1s - loss: 0.0201 - mean_absolute_error: 0.1053 - val_loss: 0.0278 - val_mean_absolute_error: 0.1107 - 779ms/epoch - 46ms/step
# Epoch 32/100
# 17/17 - 1s - loss: 0.0174 - mean_absolute_error: 0.0980 - val_loss: 0.0393 - val_mean_absolute_error: 0.1290 - 791ms/epoch - 47ms/step
# Epoch 33/100
# 17/17 - 1s - loss: 0.0257 - mean_absolute_error: 0.1128 - val_loss: 0.0262 - val_mean_absolute_error: 0.1096 - 788ms/epoch - 46ms/step
# Epoch 34/100
# 17/17 - 1s - loss: 0.0230 - mean_absolute_error: 0.1128 - val_loss: 0.0459 - val_mean_absolute_error: 0.1531 - 774ms/epoch - 46ms/step
# Epoch 35/100
# 17/17 - 1s - loss: 0.0193 - mean_absolute_error: 0.1045 - val_loss: 0.0391 - val_mean_absolute_error: 0.1265 - 741ms/epoch - 44ms/step
# Epoch 36/100
# 17/17 - 2s - loss: 0.0167 - mean_absolute_error: 0.0951 - val_loss: 0.0353 - val_mean_absolute_error: 0.1276 - 2s/epoch - 91ms/step
# Epoch 37/100
# 17/17 - 1s - loss: 0.0166 - mean_absolute_error: 0.0939 - val_loss: 0.0368 - val_mean_absolute_error: 0.1348 - 1s/epoch - 78ms/step
# Epoch 38/100
# 17/17 - 1s - loss: 0.0192 - mean_absolute_error: 0.1046 - val_loss: 0.0413 - val_mean_absolute_error: 0.1357 - 772ms/epoch - 45ms/step
# Epoch 39/100
# 17/17 - 1s - loss: 0.0189 - mean_absolute_error: 0.1058 - val_loss: 0.0342 - val_mean_absolute_error: 0.1242 - 757ms/epoch - 45ms/step
# Epoch 40/100
# 17/17 - 1s - loss: 0.0165 - mean_absolute_error: 0.0939 - val_loss: 0.0593 - val_mean_absolute_error: 0.1653 - 753ms/epoch - 44ms/step
# Epoch 41/100
# 17/17 - 1s - loss: 0.0167 - mean_absolute_error: 0.0937 - val_loss: 0.0261 - val_mean_absolute_error: 0.1056 - 771ms/epoch - 45ms/step
# Epoch 42/100
# 17/17 - 1s - loss: 0.0141 - mean_absolute_error: 0.0919 - val_loss: 0.0283 - val_mean_absolute_error: 0.1115 - 715ms/epoch - 42ms/step
# Epoch 43/100
# 17/17 - 1s - loss: 0.0137 - mean_absolute_error: 0.0871 - val_loss: 0.0459 - val_mean_absolute_error: 0.1487 - 751ms/epoch - 44ms/step
# Epoch 44/100
# 17/17 - 1s - loss: 0.0152 - mean_absolute_error: 0.0904 - val_loss: 0.0366 - val_mean_absolute_error: 0.1238 - 734ms/epoch - 43ms/step
# Epoch 45/100
# 17/17 - 1s - loss: 0.0185 - mean_absolute_error: 0.0984 - val_loss: 0.0656 - val_mean_absolute_error: 0.1683 - 744ms/epoch - 44ms/step
# Epoch 46/100
# 17/17 - 1s - loss: 0.0196 - mean_absolute_error: 0.0989 - val_loss: 0.0319 - val_mean_absolute_error: 0.1131 - 748ms/epoch - 44ms/step
# Epoch 47/100
# 17/17 - 1s - loss: 0.0132 - mean_absolute_error: 0.0840 - val_loss: 0.0355 - val_mean_absolute_error: 0.1270 - 740ms/epoch - 44ms/step
# Epoch 48/100
# 17/17 - 1s - loss: 0.0146 - mean_absolute_error: 0.0928 - val_loss: 0.0391 - val_mean_absolute_error: 0.1356 - 787ms/epoch - 46ms/step
# Epoch 49/100
# 17/17 - 1s - loss: 0.0161 - mean_absolute_error: 0.0970 - val_loss: 0.0371 - val_mean_absolute_error: 0.1225 - 730ms/epoch - 43ms/step
# Epoch 50/100
# 17/17 - 1s - loss: 0.0157 - mean_absolute_error: 0.0898 - val_loss: 0.0331 - val_mean_absolute_error: 0.1145 - 804ms/epoch - 47ms/step
# Epoch 51/100
# 17/17 - 2s - loss: 0.0148 - mean_absolute_error: 0.0873 - val_loss: 0.0533 - val_mean_absolute_error: 0.1588 - 2s/epoch - 92ms/step
# Epoch 52/100
# 17/17 - 1s - loss: 0.0155 - mean_absolute_error: 0.0865 - val_loss: 0.0354 - val_mean_absolute_error: 0.1269 - 1s/epoch - 71ms/step
# Epoch 53/100
# 17/17 - 1s - loss: 0.0144 - mean_absolute_error: 0.0871 - val_loss: 0.0483 - val_mean_absolute_error: 0.1596 - 758ms/epoch - 45ms/step
# Epoch 54/100
# 17/17 - 1s - loss: 0.0124 - mean_absolute_error: 0.0852 - val_loss: 0.0305 - val_mean_absolute_error: 0.1145 - 757ms/epoch - 45ms/step
# Epoch 55/100
# 17/17 - 1s - loss: 0.0117 - mean_absolute_error: 0.0786 - val_loss: 0.0388 - val_mean_absolute_error: 0.1284 - 759ms/epoch - 45ms/step
# Epoch 56/100
# 17/17 - 1s - loss: 0.0129 - mean_absolute_error: 0.0823 - val_loss: 0.0324 - val_mean_absolute_error: 0.1136 - 767ms/epoch - 45ms/step
# Epoch 57/100
# 17/17 - 1s - loss: 0.0140 - mean_absolute_error: 0.0889 - val_loss: 0.0453 - val_mean_absolute_error: 0.1518 - 751ms/epoch - 44ms/step
# Epoch 58/100
# 17/17 - 1s - loss: 0.0098 - mean_absolute_error: 0.0757 - val_loss: 0.0272 - val_mean_absolute_error: 0.1115 - 750ms/epoch - 44ms/step
# Epoch 59/100
# 17/17 - 1s - loss: 0.0124 - mean_absolute_error: 0.0824 - val_loss: 0.0330 - val_mean_absolute_error: 0.1214 - 722ms/epoch - 42ms/step
# Epoch 60/100
# 17/17 - 1s - loss: 0.0096 - mean_absolute_error: 0.0709 - val_loss: 0.0314 - val_mean_absolute_error: 0.1179 - 732ms/epoch - 43ms/step
# Epoch 61/100
# 17/17 - 1s - loss: 0.0123 - mean_absolute_error: 0.0801 - val_loss: 0.0362 - val_mean_absolute_error: 0.1267 - 774ms/epoch - 46ms/step
# Epoch 62/100
# 17/17 - 1s - loss: 0.0150 - mean_absolute_error: 0.0896 - val_loss: 0.0326 - val_mean_absolute_error: 0.1231 - 714ms/epoch - 42ms/step
# Epoch 63/100
# 17/17 - 1s - loss: 0.0147 - mean_absolute_error: 0.0890 - val_loss: 0.0383 - val_mean_absolute_error: 0.1380 - 744ms/epoch - 44ms/step
# Epoch 64/100
# 17/17 - 1s - loss: 0.0119 - mean_absolute_error: 0.0822 - val_loss: 0.0459 - val_mean_absolute_error: 0.1490 - 793ms/epoch - 47ms/step
# Epoch 65/100
# 17/17 - 1s - loss: 0.0086 - mean_absolute_error: 0.0705 - val_loss: 0.0352 - val_mean_absolute_error: 0.1231 - 928ms/epoch - 55ms/step
# Epoch 66/100
# 17/17 - 2s - loss: 0.0109 - mean_absolute_error: 0.0761 - val_loss: 0.0407 - val_mean_absolute_error: 0.1444 - 2s/epoch - 94ms/step
# Epoch 67/100
# 17/17 - 1s - loss: 0.0111 - mean_absolute_error: 0.0776 - val_loss: 0.0314 - val_mean_absolute_error: 0.1222 - 1s/epoch - 70ms/step
# Epoch 68/100
# 17/17 - 1s - loss: 0.0127 - mean_absolute_error: 0.0815 - val_loss: 0.0385 - val_mean_absolute_error: 0.1352 - 1s/epoch - 62ms/step
# Epoch 69/100
# 17/17 - 1s - loss: 0.0130 - mean_absolute_error: 0.0823 - val_loss: 0.0446 - val_mean_absolute_error: 0.1552 - 807ms/epoch - 47ms/step
# Epoch 70/100
# 17/17 - 1s - loss: 0.0154 - mean_absolute_error: 0.0907 - val_loss: 0.0507 - val_mean_absolute_error: 0.1715 - 745ms/epoch - 44ms/step
# Epoch 71/100
# 17/17 - 1s - loss: 0.0106 - mean_absolute_error: 0.0785 - val_loss: 0.0427 - val_mean_absolute_error: 0.1474 - 813ms/epoch - 48ms/step
# Epoch 72/100
# 17/17 - 1s - loss: 0.0098 - mean_absolute_error: 0.0714 - val_loss: 0.0300 - val_mean_absolute_error: 0.1165 - 1s/epoch - 70ms/step
# Epoch 73/100
# 17/17 - 1s - loss: 0.0107 - mean_absolute_error: 0.0761 - val_loss: 0.0309 - val_mean_absolute_error: 0.1162 - 970ms/epoch - 57ms/step
# Epoch 74/100
# 17/17 - 1s - loss: 0.0115 - mean_absolute_error: 0.0783 - val_loss: 0.0404 - val_mean_absolute_error: 0.1362 - 747ms/epoch - 44ms/step
# Epoch 75/100
# 17/17 - 1s - loss: 0.0124 - mean_absolute_error: 0.0789 - val_loss: 0.0296 - val_mean_absolute_error: 0.1179 - 799ms/epoch - 47ms/step
# Epoch 76/100
# 17/17 - 1s - loss: 0.0137 - mean_absolute_error: 0.0864 - val_loss: 0.0493 - val_mean_absolute_error: 0.1619 - 859ms/epoch - 51ms/step
# Epoch 77/100
# 17/17 - 1s - loss: 0.0141 - mean_absolute_error: 0.0898 - val_loss: 0.0383 - val_mean_absolute_error: 0.1319 - 728ms/epoch - 43ms/step
# Epoch 78/100
# 17/17 - 1s - loss: 0.0112 - mean_absolute_error: 0.0813 - val_loss: 0.0539 - val_mean_absolute_error: 0.1601 - 787ms/epoch - 46ms/step
# Epoch 79/100
# 17/17 - 2s - loss: 0.0096 - mean_absolute_error: 0.0746 - val_loss: 0.0401 - val_mean_absolute_error: 0.1368 - 2s/epoch - 105ms/step
# Epoch 80/100
# 17/17 - 1s - loss: 0.0080 - mean_absolute_error: 0.0661 - val_loss: 0.0400 - val_mean_absolute_error: 0.1340 - 1s/epoch - 79ms/step
# Epoch 81/100
# 17/17 - 1s - loss: 0.0097 - mean_absolute_error: 0.0729 - val_loss: 0.0409 - val_mean_absolute_error: 0.1381 - 744ms/epoch - 44ms/step
# Epoch 82/100
# 17/17 - 1s - loss: 0.0102 - mean_absolute_error: 0.0742 - val_loss: 0.0374 - val_mean_absolute_error: 0.1272 - 741ms/epoch - 44ms/step
# Epoch 83/100
# 17/17 - 1s - loss: 0.0095 - mean_absolute_error: 0.0764 - val_loss: 0.0489 - val_mean_absolute_error: 0.1528 - 787ms/epoch - 46ms/step
# Epoch 84/100
# 17/17 - 1s - loss: 0.0116 - mean_absolute_error: 0.0809 - val_loss: 0.0358 - val_mean_absolute_error: 0.1315 - 871ms/epoch - 51ms/step
# Epoch 85/100
# 17/17 - 1s - loss: 0.0093 - mean_absolute_error: 0.0756 - val_loss: 0.0459 - val_mean_absolute_error: 0.1451 - 828ms/epoch - 49ms/step
# Epoch 86/100
# 17/17 - 1s - loss: 0.0085 - mean_absolute_error: 0.0696 - val_loss: 0.0521 - val_mean_absolute_error: 0.1585 - 735ms/epoch - 43ms/step
# Epoch 87/100
# 17/17 - 1s - loss: 0.0087 - mean_absolute_error: 0.0720 - val_loss: 0.0480 - val_mean_absolute_error: 0.1541 - 772ms/epoch - 45ms/step
# Epoch 88/100
# 17/17 - 1s - loss: 0.0088 - mean_absolute_error: 0.0716 - val_loss: 0.0304 - val_mean_absolute_error: 0.1233 - 761ms/epoch - 45ms/step
# Epoch 89/100
# 17/17 - 1s - loss: 0.0066 - mean_absolute_error: 0.0610 - val_loss: 0.0381 - val_mean_absolute_error: 0.1235 - 775ms/epoch - 46ms/step
# Epoch 90/100
# 17/17 - 1s - loss: 0.0071 - mean_absolute_error: 0.0639 - val_loss: 0.0516 - val_mean_absolute_error: 0.1624 - 745ms/epoch - 44ms/step
# Epoch 91/100
# 17/17 - 1s - loss: 0.0073 - mean_absolute_error: 0.0635 - val_loss: 0.0352 - val_mean_absolute_error: 0.1246 - 752ms/epoch - 44ms/step
# Epoch 92/100
# 17/17 - 1s - loss: 0.0091 - mean_absolute_error: 0.0735 - val_loss: 0.0360 - val_mean_absolute_error: 0.1352 - 848ms/epoch - 50ms/step
# Epoch 93/100
# 17/17 - 1s - loss: 0.0112 - mean_absolute_error: 0.0779 - val_loss: 0.0387 - val_mean_absolute_error: 0.1378 - 1s/epoch - 75ms/step
# Epoch 94/100
# 17/17 - 2s - loss: 0.0086 - mean_absolute_error: 0.0727 - val_loss: 0.0499 - val_mean_absolute_error: 0.1631 - 2s/epoch - 91ms/step
# Epoch 95/100
# 17/17 - 1s - loss: 0.0095 - mean_absolute_error: 0.0765 - val_loss: 0.0379 - val_mean_absolute_error: 0.1384 - 855ms/epoch - 50ms/step
# Epoch 96/100
# 17/17 - 1s - loss: 0.0087 - mean_absolute_error: 0.0690 - val_loss: 0.0447 - val_mean_absolute_error: 0.1405 - 782ms/epoch - 46ms/step
# Epoch 97/100
# 17/17 - 1s - loss: 0.0093 - mean_absolute_error: 0.0729 - val_loss: 0.0354 - val_mean_absolute_error: 0.1354 - 777ms/epoch - 46ms/step
# Epoch 98/100
# 17/17 - 1s - loss: 0.0100 - mean_absolute_error: 0.0752 - val_loss: 0.0339 - val_mean_absolute_error: 0.1309 - 770ms/epoch - 45ms/step
# Epoch 99/100
# 17/17 - 1s - loss: 0.0107 - mean_absolute_error: 0.0758 - val_loss: 0.0498 - val_mean_absolute_error: 0.1500 - 759ms/epoch - 45ms/step
# Epoch 100/100
# 17/17 - 1s - loss: 0.0089 - mean_absolute_error: 0.0689 - val_loss: 0.0369 - val_mean_absolute_error: 0.1253 - 747ms/epoch - 44ms/step
